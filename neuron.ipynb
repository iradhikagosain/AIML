# %%
import torch
import torch.nn as nn

# %%
torch.manual_seed(42)
inputs=torch.tensor([1.0,2.0,3.0])

# %%
neuron=nn.Linear(in_features=3,out_features=1)

# %%
output=neuron(inputs)

# %%
output
# Out:
# tensor([-0.3977], grad_fn=<ViewBackward0>)

# %%
#verify

neuron.bias
# Out:
# Parameter containing:
# tensor([0.3391], requires_grad=True)

# %%
neuron.weight
# Out:
# Parameter containing:
# tensor([[-0.1265,  0.1165, -0.2811]], requires_grad=True)

# %%
neuron.weight @inputs + neuron.bias
# Out:
# tensor([-0.3977], grad_fn=<AddBackward0>)
