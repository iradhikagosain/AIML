# %%
import requests

# %%
URL="https://api.chucknorris.io/jokes/random"

# %%
data=requests.get(URL)

# %%
res=data.json()

# %%
import pandas as pd

# %%
df=pd.json_normalize(res)

# %%
df["value"]
# Out:
# 0    CHUCK NORRIS ONCE DONE THE SPLITS ON 2 VAN DAMMES
# Name: value, dtype: object

# %%
df["value"]
# Out:
# 0    CHUCK NORRIS ONCE DONE THE SPLITS ON 2 VAN DAMMES
# Name: value, dtype: object
