# %%
import pandas as pd

# %%
df_customers=pd.DataFrame({
    "customer_id":[1,2,3,4],
    "name":["riya","radhika","mahi","charlie"]
})

df_orders=pd.DataFrame({
    "order_id":[101,102,103,104],
    "customer_id":[2,1,4,5],
    "amount":[250,120,300,180]
})

# %%
df_customers
# Out:
#    customer_id     name
# 0            1     riya
# 1            2  radhika
# 2            3     mahi
# 3            4  charlie

# %%
df_orders
# Out:
#    order_id  customer_id  amount
# 0       101            2     250
# 1       102            1     120
# 2       103            4     300
# 3       104            5     180

# %%
pd.merge(df_customers,df_orders,on="customer_id")#inner join
# Out:
#    customer_id     name  order_id  amount
# 0            1     riya       102     120
# 1            2  radhika       101     250
# 2            4  charlie       103     300

# %%
pd.merge(df_customers,df_orders,on="customer_id",how="left")#left join
# Out:
#    customer_id     name  order_id  amount
# 0            1     riya     102.0   120.0
# 1            2  radhika     101.0   250.0
# 2            3     mahi       NaN     NaN
# 3            4  charlie     103.0   300.0

# %%
pd.merge(df_customers,df_orders,on="customer_id",how="right")#right join
# Out:
#    customer_id     name  order_id  amount
# 0            2  radhika       101     250
# 1            1     riya       102     120
# 2            4  charlie       103     300
# 3            5      NaN       104     180

# %%
pd.merge(df_customers,df_orders,on="customer_id",how="outer")#outer join
# Out:
#    customer_id     name  order_id  amount
# 0            1     riya     102.0   120.0
# 1            2  radhika     101.0   250.0
# 2            3     mahi       NaN     NaN
# 3            4  charlie     103.0   300.0
# 4            5      NaN     104.0   180.0

# %%
#concatenation

df1=pd.DataFrame({
    "id":[1,2,3],
    "name":["adam","eve","dave"]
})

df2=pd.DataFrame({
    "id":[4,5,6],
    "name":["riya","radhika","mahi"]
})

# %%
df1
# Out:
#    id  name
# 0   1  adam
# 1   2   eve
# 2   3  dave

# %%
df2
# Out:
#    id     name
# 0   4     riya
# 1   5  radhika
# 2   6     mahi

# %%
pd.concat([df1,df2])
# Out:
#    id     name
# 0   1     adam
# 1   2      eve
# 2   3     dave
# 0   4     riya
# 1   5  radhika
# 2   6     mahi

# %%
pd.concat([df1,df2],ignore_index=True)#row
# Out:
#    id     name
# 0   1     adam
# 1   2      eve
# 2   3     dave
# 3   4     riya
# 4   5  radhika
# 5   6     mahi

# %%
pd.concat([df1,df2],axis=1)#col
# Out:
#    id  name  id     name
# 0   1  adam   4     riya
# 1   2   eve   5  radhika
# 2   3  dave   6     mahi
