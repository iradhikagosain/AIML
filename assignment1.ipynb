# %%
name=input("enter your name:")
age=int(input("enter your age:"))
print(f"hello {name} , you are {age} years old")
# Out:
# enter your name: riya
# enter your age: 34
# hello riya , you are 34 years old

# %%
num1=int(input("enter num1:"))
num2=int(input("enter num2:"))
print("Add:",num1+num2)
print("difference:",num1-num2)
print("product:",num1*num2)
print("quotient:",num1/num2)
# Out:
# enter num1: 1
# enter num2: 3
# Add: 4
# difference: -2
# product: 3
# quotient: 0.3333333333333333

# %%
num1=int(input("enter num1:"))
num2=int(input("enter num2:"))
print((float(num1)+float(num2))/2)
# Out:
# enter num1: 3
# enter num2: 4
# 3.5

# %%
num1=input("enter string")
print(int(num1))
print(type((int(num1))))
print(float(num1))
print(type((float(num1))))
print(str(num1))
print(type((str(num1))))
# Out:
# enter string 45
# 45
# <class 'int'>
# 45.0
# <class 'float'>
# 45
# <class 'str'>

# %%
x = 10 + 3 * 2 ** 2
print(x)
# Out:
# 22

# %%
num1=int(input("enter num1:"))
num2=int(input("enter num2:"))
print("SWAPPING....")
x=num1
num1=num2
num2=x
print(num1)
print(num2)
# Out:
# enter num1: 6
# enter num2: 8
# SWAPPING....
# 8
# 6

# %%
temp=input("enter temperature in celsius:")
ctemp=float(temp)
ftemp=(ctemp*(9/5))+32
print("fahrenheit temp:",ftemp)
# Out:
# enter temperature in celsius: 3
# fahrenheit temp: 37.4

# %%
r=int(input("enter radius:"))
area=3.14*r*r
print(area)
# Out:
# enter radius: 3
# 28.259999999999998

# %%
p=int(input("enter principle:"))
r=int(input("enter rate of interest:"))
t=int(input("enter time:"))
si=p*r*t
print("simple interest:",si)
# Out:
# enter principle: 2
# enter rate of interest: 3
# enter time: 4
# simple interest: 24

# %%
f=float(input("enter floating number:"))
print(int(f))
print(f-int(f))
# Out:
# enter floating number: 45.78
# 45
# 0.7800000000000011
